# %% [markdown]
# <h1 style='color:orange' align='center'>Facial Image Classification<h1>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# <h3 style='color:blue'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# **When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it**

# %% [markdown]
# **Now how do you detect face and eyes?**

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this:
#
# https://pyimagesearch.com/2021/04/12/opencv-haar-cascades/#:~:text=Haar%20cascades%2C%20first%20introduced%20by,most%20popular%20object%20detection%20algorithm.

# %%
img = cv2.imread('./test_images/test.jpg')
img.shape
# Out:
# (3000, 2000, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (3000, 2000)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[826, 425, 223, 223]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (826, 425, 223, 223)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:blue'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# Decrease matplotlib output size
from matplotlib.pyplot import figure
figure(figsize=(8, 4), dpi=80)

plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (223, 223, 3)

# %% [markdown]
# <h3 style='color:blue'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %%
figure(figsize=(8, 4), dpi=80)
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (223, 223, 3)

# %% [markdown]
# <h3 style='color:blue'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# **In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc**

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
figure(figsize=(8, 4), dpi=80)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:blue'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# **Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)**

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/test.jpg')
figure(figsize=(8, 8), dpi=80)
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/test.jpg')

figure(figsize=(8, 4), dpi=80)
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/test1.jpg')

figure(figsize=(8, 6), dpi=80)
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/test1.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/Dakota_Johnson',
#  './dataset/Derek_Drouin',
#  './dataset/Elon_Musk',
#  './dataset/Narendra_Modi',
#  './dataset/Tom_Cruise']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Dakota_Johnson
# Generating cropped images in folder:  ./dataset/cropped/Derek_Drouin
# Generating cropped images in folder:  ./dataset/cropped/Elon_Musk
# Generating cropped images in folder:  ./dataset/cropped/Narendra_Modi
# Generating cropped images in folder:  ./dataset/cropped/Tom_Cruise

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Dakota_Johnson': ['./dataset/cropped/Dakota_Johnson\\Dakota_Johnson1.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson10.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson11.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson12.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson13.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson14.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson15.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson16.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson17.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson18.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson19.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson20.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson21.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson3.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson4.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson5.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson6.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson7.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson8.png',
#   './dataset/cropped/Dakota_Johnson\\Dakota_Johnson9.png'],
#  'Derek_Drouin': ['./dataset/cropped/Derek_Drouin\\Derek_Drouin1.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin10.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin11.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin12.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin13.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin14.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin2.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin3.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin4.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin5.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin6.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin7.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin8.png',
#   './dataset/cropped/Derek_Drouin\\Derek_Drouin9.png'],
#  'Elon_Musk': ['./dataset/cropped/Elon_Musk\\Elon_Musk1.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk10.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk11.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk12.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk13.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk14.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk15.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk16.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk17.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk18.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk19.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk2.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk20.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk21.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk22.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk23.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk24.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk25.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk26.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk27.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk28.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk29.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk3.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk30.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk31.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk32.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk33.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk34.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk35.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk36.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk37.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk38.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk39.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk4.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk40.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk41.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk5.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk6.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk7.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk8.png',
#   './dataset/cropped/Elon_Musk\\Elon_Musk9.png'],
#  'Narendra_Modi': ['./dataset/cropped/Narendra_Modi\\Narendra_Modi1.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi10.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi11.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi12.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi13.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi14.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi15.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi16.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi17.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi18.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi19.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi2.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi20.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi21.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi22.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi23.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi24.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi25.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi26.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi27.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi28.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi29.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi3.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi4.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi5.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi6.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi7.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi8.png',
#   './dataset/cropped/Narendra_Modi\\Narendra_Modi9.png'],
#  'Tom_Cruise': ['./dataset/cropped/Tom_Cruise\\Tom_Cruise10.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise13.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise14.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise15.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise16.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise17.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise18.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise19.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise2.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise20.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise21.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise22.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise23.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise24.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise25.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise26.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise27.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise3.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise4.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise6.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise7.png',
#   './dataset/cropped/Tom_Cruise\\Tom_Cruise8.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Dakota_Johnson': 0,
#  'Derek_Drouin': 1,
#  'Elon_Musk': 2,
#  'Narendra_Modi': 3,
#  'Tom_Cruise': 4}

# %% [markdown]
# **Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now**

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
# We did the virtual stacking of our images, therefore the size is
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[162],
#        [168],
#        [182],
#        ...,
#        [ 28],
#        [194],
#        [  6]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (126, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.75

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       1.00      0.40      0.57         5
#            2       0.60      1.00      0.75         9
#            3       1.00      0.78      0.88         9
#            4       0.50      0.33      0.40         3
#
#     accuracy                           0.75        32
#    macro avg       0.79      0.67      0.69        32
# weighted avg       0.81      0.75      0.74        32

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.787719
# 1        random_forest    0.660819
# 2  logistic_regression    0.787719
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.875

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.875

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[6, 0, 0, 0, 0],
#        [0, 5, 0, 0, 0],
#        [0, 1, 8, 0, 0],
#        [0, 0, 1, 8, 0],
#        [1, 0, 1, 0, 1]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Dakota_Johnson': 0,
#  'Derek_Drouin': 1,
#  'Elon_Musk': 2,
#  'Narendra_Modi': 3,
#  'Tom_Cruise': 4}

# %%
### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\users\aryan\appdata\roaming\python\python310\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
